# %% [markdown]
# # Tutorial 01 - Working with Spike Data
#
# The SPyke data class allows for flexible analysis of neural data, including spike sorting, wave visualization, PSTHs, and more.

# %%
# import statements
import SPyke
import matplotlib.pyplot as plt

# put matplotlib in widget mode so that we can use interactive plots
# %matplotlib widget 

# path to directory containing the TDT tank
directory = r"C://Users//coventry//DataRepos//R144-220829-160841"
data = SPyke.Spike(directory,stores = ['TDT2'])              #Load in all stores

# %%
data

# %%
 data_common_mean = data.common_reference(method='mean')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,6))
x_lim = (0,10) 
y_lim = 1
data_common_mean.plot(axis = ax2,  x_lim=x_lim, y_lim=y_lim, show=True)
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
data_common_median.plot(axis = ax2,  x_lim=x_lim, y_lim=y_lim, show=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23404\2489675620.py in <module>
# ----> 1 data_common_median.plot(axis = ax2,  x_lim=x_lim, y_lim=y_lim, show=False)
#
# NameError: name 'data_common_median' is not defined
